# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mtcars=pd.read_csv("mtcars.csv")

# %%
mtcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
for i in range(1,len(mtcars.columns)):
    temp_name=mtcars.columns[i]
    temp_mean=mtcars[temp_name].mean()
    temp_std=mtcars[temp_name].std()
    outliers_list=[]
    for j in mtcars[temp_name]:
        z_value=(j-temp_mean)/temp_std
        #print(z_value)
        if abs(z_value)>3:
            outliers_list.append(j)
    print ("Outliers of column",temp_name,"are: ",outliers_list)
# Out:
# Outliers of column mpg are:  []
# Outliers of column cyl are:  []
# Outliers of column disp are:  []
# Outliers of column hp are:  []
# Outliers of column drat are:  []
# Outliers of column wt are:  []
# Outliers of column qsec are:  []
# Outliers of column vs are:  []
# Outliers of column am are:  []
# Outliers of column gear are:  []
# Outliers of column carb are:  [8]

# %%
sns.boxplot(data=mtcars,orient="v")

# %%
from sklearn.datasets import load_boston
boston_ds = load_boston()

# %%
target_col=boston_ds.target
target_mean=target_col.mean()
target_std=target_col.std()

outliers_list2=[]

for k in target_col:
    #print(k)
    z_value=(target_mean-k)/target_std
    #print(z_value)
    if abs(z_value)>3:
        outliers_list2.append(k)
        
print (outliers_list2)
# Out:
# -0.1596856587150597
# 0.1015242873296184
# -1.3242466681642504
# -1.1827579473900494
# -1.4875028844421743
# -0.6712218030525545
# -0.039964433444582
# -0.4970818390227692
# 0.6565954226745598
# 0.3953854766298817
# 0.8198516389524837
# 0.3953854766298817
# 0.09064053957775704
# 0.23212926035195783
# 0.47157171089291283
# 0.28654799911126577
# -0.061731928948305495
# 0.5477579451559439
# 0.25389675585568094
# 0.47157171089291283
# 0.972224107478546
# 0.31919924236685027
# 0.7980841434487606
# 0.8742703777117917
# 0.7545491524413142
# 0.9395728642229612
# 0.6457116749226981
# 0.8416191344562068
# 0.4498042153891897
# 0.16682677384078812
# 1.0701778372453004
# 0.8742703777117917
# 1.0157590984859926
# 1.026642846237854
# 0.9831078552304076
# 0.3953854766298817
# 0.27566425135940403
# 0.16682677384078812
# -0.23587189297809075
# -0.8997805058416481
# -1.3460141636679732
# -0.4426631002634613
# -0.30117437948926046
# -0.23587189297809075
# 0.145059278337065
# 0.35185048562243515
# ...
